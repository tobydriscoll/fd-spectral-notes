# %% [markdown]
# # A title

# %%
using Plots

# %%
plotlyjs()
# Out:
# Plots.PlotlyJSBackend()

# %%
surface(rand(40,40))
# Out:
#     <div id="6812c1c8-7bf6-4e0f-8591-f8f4ed62dd38" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('6812c1c8-7bf6-4e0f-8591-f8f4ed62dd38', [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "colorscale": [
#             [
#                 0.0,
#                 "rgba(0, 0, 4, 1.000)"
#             ],
#             [
#                 0.00392156862745098,
#                 "rgba(1, 0, 5, 1.000)"
#             ],
#             [
#                 0.00784313725490196,
#                 "rgba(1, 1, 6, 1.000)"
#             ],
#             [
#                 0.011764705882352941,
#                 "rgba(1, 1, 8, 1.000)"
#             ],
#             [
#                 0.01568627450980392,
# ...

# %%
gui()
# Out:
# data: [
#   "surface with fields colorbar, colorscale, name, opacity, scene, showlegend, showscale, transpose, type, x, xaxis, y, yaxis, z, zaxis, zmax, and zmin"
# ]
#
# layout: "layout with fields annotations, height, legend, legend_position, margin, paper_bgcolor, plot_bgcolor, scene, showlegend, template, and width"

# %%
import Pkg; Pkg.status()
# Out:
# Status `~/Dropbox/class/817/notes/Project.toml`
#   [6e4b80f9] BenchmarkTools v1.3.1
#   [8e7c35d0] BlockArrays v0.16.20
#   [7a1cc6ca] FFTW v1.5.0
#   [7073ff75] IJulia v1.23.3
#   [ba0b0d4f] Krylov v0.8.3
#   [7a12625a] LinearMaps v3.8.0
#   [2774e3e8] NLsolve v4.5.1
#   [1dea7af3] OrdinaryDiffEq v6.25.0
#   [f0f68f2c] PlotlyJS v0.18.8
#   [91a5bcdd] Plots v1.31.7
# ⌃ [c3e4b0f8] Pluto v0.19.9
#   [08abe8d2] PrettyTables v1.3.1
#   [5f89f4a4] PyFormattedStrings v0.1.10
#   [0f1e0344] WebIO v0.8.18
#   [37e2e46d] LinearAlgebra
# Info Packages marked with ⌃ have new versions available

# %%
Pkg.add("Blink")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#     Updating `~/Dropbox/class/817/notes/Project.toml`
#   [ad839575] + Blink v0.12.5
#   No Changes to `~/Dropbox/class/817/notes/Manifest.toml`
